# %%
from tensorflow.keras.models import load_model
import os

# %%
# 📁 Ruta relativa al modelo
modelo_path = os.path.join("..", "models", "conv_MLP_84.h5")

# 🔍 Cargar el modelo
modelo = load_model(modelo_path)

# %%
# 📊 Resumen de arquitectura
modelo.summary()
# Out:
# Model: "Net5Blocks"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 512, 512, 16  160         ['input_9[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 512, 512, 16  64          ['conv1[0][0]']
#                                 )
#
#  conv2 (Conv2D)                 (None, 512, 512, 16  2320        ['bn_conv1[0][0]']
#                                 )
#
#  conv1skip (Conv2D)             (None, 512, 512, 16  32          ['input_9[0][0]']
#                                 )
#
#  bn_conv2 (BatchNormalization)  (None, 512, 512, 16  64          ['conv2[0][0]']
#                                 )
#
#  bn_conv1skp (BatchNormalizatio  (None, 512, 512, 16  64         ['conv1skip[0][0]']
#  n)                             )
#
#  add_16 (Add)                   (None, 512, 512, 16  0           ['bn_conv2[0][0]',
#                                 )                                 'bn_conv1skp[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 255, 255, 16  0          ['add_16[0][0]']
#  )                              )
#
#  conv3 (Conv2D)                 (None, 255, 255, 32  4640        ['max_pooling2d_10[0][0]']
#                                 )
#
#  bn_conv3 (BatchNormalization)  (None, 255, 255, 32  128         ['conv3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 255, 255, 32  0           ['bn_conv3[0][0]']
#                                 )
#
#  conv4 (Conv2D)                 (None, 255, 255, 32  9248        ['activation_16[0][0]']
#                                 )
#
#  conv2skip (Conv2D)             (None, 255, 255, 32  544         ['max_pooling2d_10[0][0]']
#                                 )
#
#  bn_conv4 (BatchNormalization)  (None, 255, 255, 32  128         ['conv4[0][0]']
#                                 )
#
#  bn_conv2skp (BatchNormalizatio  (None, 255, 255, 32  128        ['conv2skip[0][0]']
#  n)                             )
#
#  add_17 (Add)                   (None, 255, 255, 32  0           ['bn_conv4[0][0]',
#                                 )                                 'bn_conv2skp[0][0]']
#
#  activation_17 (Activation)     (None, 255, 255, 32  0           ['add_17[0][0]']
#                                 )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 127, 127, 32  0          ['activation_17[0][0]']
#  )                              )
#
#  conv5 (Conv2D)                 (None, 127, 127, 48  13872       ['max_pooling2d_11[0][0]']
#                                 )
#
#  bn_conv5 (BatchNormalization)  (None, 127, 127, 48  192         ['conv5[0][0]']
#                                 )
#
#  activation_18 (Activation)     (None, 127, 127, 48  0           ['bn_conv5[0][0]']
#                                 )
#
#  conv6 (Conv2D)                 (None, 127, 127, 48  20784       ['activation_18[0][0]']
#                                 )
#
#  conv3skip (Conv2D)             (None, 127, 127, 48  1584        ['max_pooling2d_11[0][0]']
#                                 )
#
#  bn_conv6 (BatchNormalization)  (None, 127, 127, 48  192         ['conv6[0][0]']
#                                 )
#
#  bn_conv3skp (BatchNormalizatio  (None, 127, 127, 48  192        ['conv3skip[0][0]']
#  n)                             )
#
#  add_18 (Add)                   (None, 127, 127, 48  0           ['bn_conv6[0][0]',
#                                 )                                 'bn_conv3skp[0][0]']
#
#  activation_19 (Activation)     (None, 127, 127, 48  0           ['add_18[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 63, 63, 48)  0           ['activation_19[0][0]']
#  )
#
#  conv7 (Conv2D)                 (None, 63, 63, 64)   27712       ['max_pooling2d_12[0][0]']
#
#  bn_conv7 (BatchNormalization)  (None, 63, 63, 64)   256         ['conv7[0][0]']
#
#  activation_20 (Activation)     (None, 63, 63, 64)   0           ['bn_conv7[0][0]']
#
#  dropout_3 (Dropout)            (None, 63, 63, 64)   0           ['activation_20[0][0]']
#
#  conv8 (Conv2D)                 (None, 63, 63, 64)   36928       ['dropout_3[0][0]']
#
#  conv4skip (Conv2D)             (None, 63, 63, 64)   3136        ['max_pooling2d_12[0][0]']
#
#  bn_conv8 (BatchNormalization)  (None, 63, 63, 64)   256         ['conv8[0][0]']
#
#  bn_conv4skp (BatchNormalizatio  (None, 63, 63, 64)  256         ['conv4skip[0][0]']
#  n)
#
#  add_19 (Add)                   (None, 63, 63, 64)   0           ['bn_conv8[0][0]',
#                                                                   'bn_conv4skp[0][0]']
#
#  activation_21 (Activation)     (None, 63, 63, 64)   0           ['add_19[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 31, 31, 64)  0           ['activation_21[0][0]']
#  )
#
#  conv9 (Conv2D)                 (None, 31, 31, 128)  73856       ['max_pooling2d_13[0][0]']
#
#  bn_conv9 (BatchNormalization)  (None, 31, 31, 128)  512         ['conv9[0][0]']
#
#  activation_22 (Activation)     (None, 31, 31, 128)  0           ['bn_conv9[0][0]']
#
#  dropout_4 (Dropout)            (None, 31, 31, 128)  0           ['activation_22[0][0]']
#
#  conv10_thisone (Conv2D)        (None, 31, 31, 128)  147584      ['dropout_4[0][0]']
#
#  conv5skip (Conv2D)             (None, 31, 31, 128)  8320        ['max_pooling2d_13[0][0]']
#
#  bn_conv10 (BatchNormalization)  (None, 31, 31, 128)  512        ['conv10_thisone[0][0]']
#
#  bn_conv5skp (BatchNormalizatio  (None, 31, 31, 128)  512        ['conv5skip[0][0]']
#  n)
#
#  add_20 (Add)                   (None, 31, 31, 128)  0           ['bn_conv10[0][0]',
#                                                                   'bn_conv5skp[0][0]']
#
#  activation_23 (Activation)     (None, 31, 31, 128)  0           ['add_20[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 15, 15, 128)  0          ['activation_23[0][0]']
#  )
#
#  average_pooling2d_2 (AveragePo  (None, 8, 8, 128)   0           ['max_pooling2d_14[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 8192)         0           ['average_pooling2d_2[0][0]']
#
#  fc1 (Dense)                    (None, 1024)         8389632     ['flatten_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 1024)         0           ['fc1[0][0]']
#
#  fc2 (Dense)                    (None, 1024)         1049600     ['dropout_5[0][0]']
#
#  fc3 (Dense)                    (None, 3)            3075        ['fc2[0][0]']
#
# ==================================================================================================
# Total params: 9,796,483
# Trainable params: 9,794,755
# Non-trainable params: 1,728
# __________________________________________________________________________________________________

# %%
# Inspección detallada de capas
for i, layer in enumerate(modelo.layers):
    print(f"{i:02d} | {layer.name:<30} | {layer.__class__.__name__:<20} | Output shape: {layer.output_shape}")
# Out:
# 00 | input_9                        | InputLayer           | Output shape: [(None, 512, 512, 1)]
# 01 | conv1                          | Conv2D               | Output shape: (None, 512, 512, 16)
# 02 | bn_conv1                       | BatchNormalization   | Output shape: (None, 512, 512, 16)
# 03 | conv2                          | Conv2D               | Output shape: (None, 512, 512, 16)
# 04 | conv1skip                      | Conv2D               | Output shape: (None, 512, 512, 16)
# 05 | bn_conv2                       | BatchNormalization   | Output shape: (None, 512, 512, 16)
# 06 | bn_conv1skp                    | BatchNormalization   | Output shape: (None, 512, 512, 16)
# 07 | add_16                         | Add                  | Output shape: (None, 512, 512, 16)
# 08 | max_pooling2d_10               | MaxPooling2D         | Output shape: (None, 255, 255, 16)
# 09 | conv3                          | Conv2D               | Output shape: (None, 255, 255, 32)
# 10 | bn_conv3                       | BatchNormalization   | Output shape: (None, 255, 255, 32)
# 11 | activation_16                  | Activation           | Output shape: (None, 255, 255, 32)
# 12 | conv4                          | Conv2D               | Output shape: (None, 255, 255, 32)
# 13 | conv2skip                      | Conv2D               | Output shape: (None, 255, 255, 32)
# 14 | bn_conv4                       | BatchNormalization   | Output shape: (None, 255, 255, 32)
# 15 | bn_conv2skp                    | BatchNormalization   | Output shape: (None, 255, 255, 32)
# 16 | add_17                         | Add                  | Output shape: (None, 255, 255, 32)
# 17 | activation_17                  | Activation           | Output shape: (None, 255, 255, 32)
# 18 | max_pooling2d_11               | MaxPooling2D         | Output shape: (None, 127, 127, 32)
# 19 | conv5                          | Conv2D               | Output shape: (None, 127, 127, 48)
# 20 | bn_conv5                       | BatchNormalization   | Output shape: (None, 127, 127, 48)
# 21 | activation_18                  | Activation           | Output shape: (None, 127, 127, 48)
# 22 | conv6                          | Conv2D               | Output shape: (None, 127, 127, 48)
# 23 | conv3skip                      | Conv2D               | Output shape: (None, 127, 127, 48)
# 24 | bn_conv6                       | BatchNormalization   | Output shape: (None, 127, 127, 48)
# 25 | bn_conv3skp                    | BatchNormalization   | Output shape: (None, 127, 127, 48)
# 26 | add_18                         | Add                  | Output shape: (None, 127, 127, 48)
# 27 | activation_19                  | Activation           | Output shape: (None, 127, 127, 48)
# 28 | max_pooling2d_12               | MaxPooling2D         | Output shape: (None, 63, 63, 48)
# 29 | conv7                          | Conv2D               | Output shape: (None, 63, 63, 64)
# 30 | bn_conv7                       | BatchNormalization   | Output shape: (None, 63, 63, 64)
# 31 | activation_20                  | Activation           | Output shape: (None, 63, 63, 64)
# 32 | dropout_3                      | Dropout              | Output shape: (None, 63, 63, 64)
# 33 | conv8                          | Conv2D               | Output shape: (None, 63, 63, 64)
# 34 | conv4skip                      | Conv2D               | Output shape: (None, 63, 63, 64)
# 35 | bn_conv8                       | BatchNormalization   | Output shape: (None, 63, 63, 64)
# 36 | bn_conv4skp                    | BatchNormalization   | Output shape: (None, 63, 63, 64)
# 37 | add_19                         | Add                  | Output shape: (None, 63, 63, 64)
# 38 | activation_21                  | Activation           | Output shape: (None, 63, 63, 64)
# 39 | max_pooling2d_13               | MaxPooling2D         | Output shape: (None, 31, 31, 64)
# 40 | conv9                          | Conv2D               | Output shape: (None, 31, 31, 128)
# 41 | bn_conv9                       | BatchNormalization   | Output shape: (None, 31, 31, 128)
# 42 | activation_22                  | Activation           | Output shape: (None, 31, 31, 128)
# 43 | dropout_4                      | Dropout              | Output shape: (None, 31, 31, 128)
# 44 | conv10_thisone                 | Conv2D               | Output shape: (None, 31, 31, 128)
# 45 | conv5skip                      | Conv2D               | Output shape: (None, 31, 31, 128)
# 46 | bn_conv10                      | BatchNormalization   | Output shape: (None, 31, 31, 128)
# 47 | bn_conv5skp                    | BatchNormalization   | Output shape: (None, 31, 31, 128)
# 48 | add_20                         | Add                  | Output shape: (None, 31, 31, 128)
# 49 | activation_23                  | Activation           | Output shape: (None, 31, 31, 128)
# 50 | max_pooling2d_14               | MaxPooling2D         | Output shape: (None, 15, 15, 128)
# 51 | average_pooling2d_2            | AveragePooling2D     | Output shape: (None, 8, 8, 128)
# 52 | flatten_2                      | Flatten              | Output shape: (None, 8192)
# 53 | fc1                            | Dense                | Output shape: (None, 1024)
# 54 | dropout_5                      | Dropout              | Output shape: (None, 1024)
# 55 | fc2                            | Dense                | Output shape: (None, 1024)
# 56 | fc3                            | Dense                | Output shape: (None, 3)

# %%
# Visualización tipo árbol (simple)
def visualizar_estructura(model):
    print("📐 Estructura del modelo:")
    for layer in model.layers:
        print(f"🔹 {layer.name} ({layer.__class__.__name__}) → {layer.output_shape}")

visualizar_estructura(modelo)
# Out:
# 📐 Estructura del modelo:
# 🔹 input_9 (InputLayer) → [(None, 512, 512, 1)]
# 🔹 conv1 (Conv2D) → (None, 512, 512, 16)
# 🔹 bn_conv1 (BatchNormalization) → (None, 512, 512, 16)
# 🔹 conv2 (Conv2D) → (None, 512, 512, 16)
# 🔹 conv1skip (Conv2D) → (None, 512, 512, 16)
# 🔹 bn_conv2 (BatchNormalization) → (None, 512, 512, 16)
# 🔹 bn_conv1skp (BatchNormalization) → (None, 512, 512, 16)
# 🔹 add_16 (Add) → (None, 512, 512, 16)
# 🔹 max_pooling2d_10 (MaxPooling2D) → (None, 255, 255, 16)
# 🔹 conv3 (Conv2D) → (None, 255, 255, 32)
# 🔹 bn_conv3 (BatchNormalization) → (None, 255, 255, 32)
# 🔹 activation_16 (Activation) → (None, 255, 255, 32)
# 🔹 conv4 (Conv2D) → (None, 255, 255, 32)
# 🔹 conv2skip (Conv2D) → (None, 255, 255, 32)
# 🔹 bn_conv4 (BatchNormalization) → (None, 255, 255, 32)
# 🔹 bn_conv2skp (BatchNormalization) → (None, 255, 255, 32)
# 🔹 add_17 (Add) → (None, 255, 255, 32)
# 🔹 activation_17 (Activation) → (None, 255, 255, 32)
# 🔹 max_pooling2d_11 (MaxPooling2D) → (None, 127, 127, 32)
# 🔹 conv5 (Conv2D) → (None, 127, 127, 48)
# 🔹 bn_conv5 (BatchNormalization) → (None, 127, 127, 48)
# 🔹 activation_18 (Activation) → (None, 127, 127, 48)
# 🔹 conv6 (Conv2D) → (None, 127, 127, 48)
# 🔹 conv3skip (Conv2D) → (None, 127, 127, 48)
# 🔹 bn_conv6 (BatchNormalization) → (None, 127, 127, 48)
# 🔹 bn_conv3skp (BatchNormalization) → (None, 127, 127, 48)
# 🔹 add_18 (Add) → (None, 127, 127, 48)
# 🔹 activation_19 (Activation) → (None, 127, 127, 48)
# 🔹 max_pooling2d_12 (MaxPooling2D) → (None, 63, 63, 48)
# 🔹 conv7 (Conv2D) → (None, 63, 63, 64)
# 🔹 bn_conv7 (BatchNormalization) → (None, 63, 63, 64)
# 🔹 activation_20 (Activation) → (None, 63, 63, 64)
# 🔹 dropout_3 (Dropout) → (None, 63, 63, 64)
# 🔹 conv8 (Conv2D) → (None, 63, 63, 64)
# 🔹 conv4skip (Conv2D) → (None, 63, 63, 64)
# 🔹 bn_conv8 (BatchNormalization) → (None, 63, 63, 64)
# 🔹 bn_conv4skp (BatchNormalization) → (None, 63, 63, 64)
# 🔹 add_19 (Add) → (None, 63, 63, 64)
# 🔹 activation_21 (Activation) → (None, 63, 63, 64)
# 🔹 max_pooling2d_13 (MaxPooling2D) → (None, 31, 31, 64)
# 🔹 conv9 (Conv2D) → (None, 31, 31, 128)
# 🔹 bn_conv9 (BatchNormalization) → (None, 31, 31, 128)
# 🔹 activation_22 (Activation) → (None, 31, 31, 128)
# 🔹 dropout_4 (Dropout) → (None, 31, 31, 128)
# 🔹 conv10_thisone (Conv2D) → (None, 31, 31, 128)
# 🔹 conv5skip (Conv2D) → (None, 31, 31, 128)
# 🔹 bn_conv10 (BatchNormalization) → (None, 31, 31, 128)
# 🔹 bn_conv5skp (BatchNormalization) → (None, 31, 31, 128)
# 🔹 add_20 (Add) → (None, 31, 31, 128)
# 🔹 activation_23 (Activation) → (None, 31, 31, 128)
# 🔹 max_pooling2d_14 (MaxPooling2D) → (None, 15, 15, 128)
# 🔹 average_pooling2d_2 (AveragePooling2D) → (None, 8, 8, 128)
# 🔹 flatten_2 (Flatten) → (None, 8192)
# 🔹 fc1 (Dense) → (None, 1024)
# 🔹 dropout_5 (Dropout) → (None, 1024)
# 🔹 fc2 (Dense) → (None, 1024)
# 🔹 fc3 (Dense) → (None, 3)

# %%
# !pip install prettytable
# Out:
# Collecting prettytable
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: wcwidth in c:\users\camil\onedrive\documentos\neumonia\detector-neumonia-uao\venv\lib\site-packages (from prettytable) (0.2.14)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.17.0

# %%
from prettytable import PrettyTable



tabla = PrettyTable(["#","Capa","Tipo","Salida","Params"])
for i, layer in enumerate(modelo.layers):
    tabla.add_row([
        i,
        layer.name,
        layer.__class__.__name__,
        layer.output_shape if hasattr(layer, "output_shape") else "-",
        layer.count_params()
    ])

print(tabla)
# Out:
# +----+---------------------+--------------------+-----------------------+---------+
# | #  |         Capa        |        Tipo        |         Salida        |  Params |
# +----+---------------------+--------------------+-----------------------+---------+
# | 0  |       input_9       |     InputLayer     | [(None, 512, 512, 1)] |    0    |
# | 1  |        conv1        |       Conv2D       |  (None, 512, 512, 16) |   160   |
# | 2  |       bn_conv1      | BatchNormalization |  (None, 512, 512, 16) |    64   |
# | 3  |        conv2        |       Conv2D       |  (None, 512, 512, 16) |   2320  |
# | 4  |      conv1skip      |       Conv2D       |  (None, 512, 512, 16) |    32   |
# | 5  |       bn_conv2      | BatchNormalization |  (None, 512, 512, 16) |    64   |
# | 6  |     bn_conv1skp     | BatchNormalization |  (None, 512, 512, 16) |    64   |
# | 7  |        add_16       |        Add         |  (None, 512, 512, 16) |    0    |
# | 8  |   max_pooling2d_10  |    MaxPooling2D    |  (None, 255, 255, 16) |    0    |
# | 9  |        conv3        |       Conv2D       |  (None, 255, 255, 32) |   4640  |
# | 10 |       bn_conv3      | BatchNormalization |  (None, 255, 255, 32) |   128   |
# | 11 |    activation_16    |     Activation     |  (None, 255, 255, 32) |    0    |
# | 12 |        conv4        |       Conv2D       |  (None, 255, 255, 32) |   9248  |
# | 13 |      conv2skip      |       Conv2D       |  (None, 255, 255, 32) |   544   |
# | 14 |       bn_conv4      | BatchNormalization |  (None, 255, 255, 32) |   128   |
# | 15 |     bn_conv2skp     | BatchNormalization |  (None, 255, 255, 32) |   128   |
# | 16 |        add_17       |        Add         |  (None, 255, 255, 32) |    0    |
# | 17 |    activation_17    |     Activation     |  (None, 255, 255, 32) |    0    |
# | 18 |   max_pooling2d_11  |    MaxPooling2D    |  (None, 127, 127, 32) |    0    |
# | 19 |        conv5        |       Conv2D       |  (None, 127, 127, 48) |  13872  |
# | 20 |       bn_conv5      | BatchNormalization |  (None, 127, 127, 48) |   192   |
# | 21 |    activation_18    |     Activation     |  (None, 127, 127, 48) |    0    |
# | 22 |        conv6        |       Conv2D       |  (None, 127, 127, 48) |  20784  |
# | 23 |      conv3skip      |       Conv2D       |  (None, 127, 127, 48) |   1584  |
# | 24 |       bn_conv6      | BatchNormalization |  (None, 127, 127, 48) |   192   |
# | 25 |     bn_conv3skp     | BatchNormalization |  (None, 127, 127, 48) |   192   |
# | 26 |        add_18       |        Add         |  (None, 127, 127, 48) |    0    |
# | 27 |    activation_19    |     Activation     |  (None, 127, 127, 48) |    0    |
# | 28 |   max_pooling2d_12  |    MaxPooling2D    |   (None, 63, 63, 48)  |    0    |
# | 29 |        conv7        |       Conv2D       |   (None, 63, 63, 64)  |  27712  |
# | 30 |       bn_conv7      | BatchNormalization |   (None, 63, 63, 64)  |   256   |
# | 31 |    activation_20    |     Activation     |   (None, 63, 63, 64)  |    0    |
# | 32 |      dropout_3      |      Dropout       |   (None, 63, 63, 64)  |    0    |
# | 33 |        conv8        |       Conv2D       |   (None, 63, 63, 64)  |  36928  |
# | 34 |      conv4skip      |       Conv2D       |   (None, 63, 63, 64)  |   3136  |
# | 35 |       bn_conv8      | BatchNormalization |   (None, 63, 63, 64)  |   256   |
# | 36 |     bn_conv4skp     | BatchNormalization |   (None, 63, 63, 64)  |   256   |
# | 37 |        add_19       |        Add         |   (None, 63, 63, 64)  |    0    |
# | 38 |    activation_21    |     Activation     |   (None, 63, 63, 64)  |    0    |
# | 39 |   max_pooling2d_13  |    MaxPooling2D    |   (None, 31, 31, 64)  |    0    |
# | 40 |        conv9        |       Conv2D       |  (None, 31, 31, 128)  |  73856  |
# | 41 |       bn_conv9      | BatchNormalization |  (None, 31, 31, 128)  |   512   |
# | 42 |    activation_22    |     Activation     |  (None, 31, 31, 128)  |    0    |
# | 43 |      dropout_4      |      Dropout       |  (None, 31, 31, 128)  |    0    |
# | 44 |    conv10_thisone   |       Conv2D       |  (None, 31, 31, 128)  |  147584 |
# | 45 |      conv5skip      |       Conv2D       |  (None, 31, 31, 128)  |   8320  |
# | 46 |      bn_conv10      | BatchNormalization |  (None, 31, 31, 128)  |   512   |
# | 47 |     bn_conv5skp     | BatchNormalization |  (None, 31, 31, 128)  |   512   |
# | 48 |        add_20       |        Add         |  (None, 31, 31, 128)  |    0    |
# | 49 |    activation_23    |     Activation     |  (None, 31, 31, 128)  |    0    |
# | 50 |   max_pooling2d_14  |    MaxPooling2D    |  (None, 15, 15, 128)  |    0    |
# | 51 | average_pooling2d_2 |  AveragePooling2D  |   (None, 8, 8, 128)   |    0    |
# | 52 |      flatten_2      |      Flatten       |      (None, 8192)     |    0    |
# | 53 |         fc1         |       Dense        |      (None, 1024)     | 8389632 |
# | 54 |      dropout_5      |      Dropout       |      (None, 1024)     |    0    |
# | 55 |         fc2         |       Dense        |      (None, 1024)     | 1049600 |
# | 56 |         fc3         |       Dense        |       (None, 3)       |   3075  |
# +----+---------------------+--------------------+-----------------------+---------+

# %%
import json

with open("modelo.json", "w") as f:
    f.write(json.dumps(json.loads(modelo.to_json()), indent=4))

# %%
for i, layer in enumerate(modelo.layers):
    print(f"{i:02d} | {layer.name:20} | {layer.__class__.__name__:20} | output: {layer.output_shape}")
# Out:
# 00 | input_9              | InputLayer           | output: [(None, 512, 512, 1)]
# 01 | conv1                | Conv2D               | output: (None, 512, 512, 16)
# 02 | bn_conv1             | BatchNormalization   | output: (None, 512, 512, 16)
# 03 | conv2                | Conv2D               | output: (None, 512, 512, 16)
# 04 | conv1skip            | Conv2D               | output: (None, 512, 512, 16)
# 05 | bn_conv2             | BatchNormalization   | output: (None, 512, 512, 16)
# 06 | bn_conv1skp          | BatchNormalization   | output: (None, 512, 512, 16)
# 07 | add_16               | Add                  | output: (None, 512, 512, 16)
# 08 | max_pooling2d_10     | MaxPooling2D         | output: (None, 255, 255, 16)
# 09 | conv3                | Conv2D               | output: (None, 255, 255, 32)
# 10 | bn_conv3             | BatchNormalization   | output: (None, 255, 255, 32)
# 11 | activation_16        | Activation           | output: (None, 255, 255, 32)
# 12 | conv4                | Conv2D               | output: (None, 255, 255, 32)
# 13 | conv2skip            | Conv2D               | output: (None, 255, 255, 32)
# 14 | bn_conv4             | BatchNormalization   | output: (None, 255, 255, 32)
# 15 | bn_conv2skp          | BatchNormalization   | output: (None, 255, 255, 32)
# 16 | add_17               | Add                  | output: (None, 255, 255, 32)
# 17 | activation_17        | Activation           | output: (None, 255, 255, 32)
# 18 | max_pooling2d_11     | MaxPooling2D         | output: (None, 127, 127, 32)
# 19 | conv5                | Conv2D               | output: (None, 127, 127, 48)
# 20 | bn_conv5             | BatchNormalization   | output: (None, 127, 127, 48)
# 21 | activation_18        | Activation           | output: (None, 127, 127, 48)
# 22 | conv6                | Conv2D               | output: (None, 127, 127, 48)
# 23 | conv3skip            | Conv2D               | output: (None, 127, 127, 48)
# 24 | bn_conv6             | BatchNormalization   | output: (None, 127, 127, 48)
# 25 | bn_conv3skp          | BatchNormalization   | output: (None, 127, 127, 48)
# 26 | add_18               | Add                  | output: (None, 127, 127, 48)
# 27 | activation_19        | Activation           | output: (None, 127, 127, 48)
# 28 | max_pooling2d_12     | MaxPooling2D         | output: (None, 63, 63, 48)
# 29 | conv7                | Conv2D               | output: (None, 63, 63, 64)
# 30 | bn_conv7             | BatchNormalization   | output: (None, 63, 63, 64)
# 31 | activation_20        | Activation           | output: (None, 63, 63, 64)
# 32 | dropout_3            | Dropout              | output: (None, 63, 63, 64)
# 33 | conv8                | Conv2D               | output: (None, 63, 63, 64)
# 34 | conv4skip            | Conv2D               | output: (None, 63, 63, 64)
# 35 | bn_conv8             | BatchNormalization   | output: (None, 63, 63, 64)
# 36 | bn_conv4skp          | BatchNormalization   | output: (None, 63, 63, 64)
# 37 | add_19               | Add                  | output: (None, 63, 63, 64)
# 38 | activation_21        | Activation           | output: (None, 63, 63, 64)
# 39 | max_pooling2d_13     | MaxPooling2D         | output: (None, 31, 31, 64)
# 40 | conv9                | Conv2D               | output: (None, 31, 31, 128)
# 41 | bn_conv9             | BatchNormalization   | output: (None, 31, 31, 128)
# 42 | activation_22        | Activation           | output: (None, 31, 31, 128)
# 43 | dropout_4            | Dropout              | output: (None, 31, 31, 128)
# 44 | conv10_thisone       | Conv2D               | output: (None, 31, 31, 128)
# 45 | conv5skip            | Conv2D               | output: (None, 31, 31, 128)
# 46 | bn_conv10            | BatchNormalization   | output: (None, 31, 31, 128)
# 47 | bn_conv5skp          | BatchNormalization   | output: (None, 31, 31, 128)
# 48 | add_20               | Add                  | output: (None, 31, 31, 128)
# 49 | activation_23        | Activation           | output: (None, 31, 31, 128)
# 50 | max_pooling2d_14     | MaxPooling2D         | output: (None, 15, 15, 128)
# 51 | average_pooling2d_2  | AveragePooling2D     | output: (None, 8, 8, 128)
# 52 | flatten_2            | Flatten              | output: (None, 8192)
# 53 | fc1                  | Dense                | output: (None, 1024)
# 54 | dropout_5            | Dropout              | output: (None, 1024)
# 55 | fc2                  | Dense                | output: (None, 1024)
# 56 | fc3                  | Dense                | output: (None, 3)
